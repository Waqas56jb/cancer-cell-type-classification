# %% [markdown]
# # Cancer Cell Classification and Clustering Report
#
# ## Introduction
# This project focuses on the development of machine learning and deep learning models to classify cell types and detect cancerous cells using a medical imaging dataset. The dataset, sourced from a custom CSV file (`data_labels_mainData.csv`) and corresponding images stored in a `dataset/images` folder, contains 186 examples with features such as `ImageName`, `cellTypeName`, `cellType`, and `isCancerous`. The primary objectives are to predict cell types (e.g., fibroblast, inflammatory, epithelial, others) and determine whether a cell is cancerous (binary classification: 0 for non-cancerous, 1 for cancerous). Additionally, unsupervised clustering techniques are employed to identify inherent patterns in the data, aiding in early diagnosis and treatment planning for improved patient outcomes.
#
# ## Tools and Technologies
# The project leverages a robust set of tools and libraries to process data, train models, and visualize results:
# - **Python**: Core programming language for implementation.
# - **Pandas**: Used for data manipulation and analysis of the CSV dataset.
# - **NumPy**: Facilitates numerical computations and array operations.
# - **Scikit-learn**: Provides machine learning algorithms (Logistic Regression, Random Forest, K-Means, Hierarchical Clustering) and utilities (train-test split, cross-validation, scaling).
# - **TensorFlow/Keras**: Enables the construction and training of a Convolutional Neural Network (CNN) for image-based classification.
# - **Matplotlib & Seaborn**: Employed for creating visualizations such as bar plots, confusion matrices, ROC curves, and clustering dendrograms.
# - **Pillow**: Handles image loading and preprocessing.
# - **SciPy**: Supports hierarchical clustering visualization.
# - **Joblib**: Used for saving trained machine learning models.
# - **Jupyter Notebook**: Environment for interactive development and documentation.
#
# The project is managed within a virtual environment (`venv`) to isolate dependencies, with all required libraries listed in `requirements.txt` for reproducibility.
#
# ## Models
# The project implements a variety of supervised and unsupervised learning models to address the classification and clustering tasks:
# - **Logistic Regression**: A linear model applied for binary classification of cancerous cells, using `cellTypeName` and `cellType` as features.
# - **Random Forest**: An ensemble method with 100 trees, enhancing robustness in classifying cancer status and cell types.
# - **Convolutional Neural Network (CNN)**: A deep learning model designed for image-based classification, featuring two convolutional layers (32 and 64 filters), max-pooling, a dense layer (128 units), dropout (0.5), and a sigmoid output layer.
# - **K-Means Clustering**: Groups similar cells into 4 clusters based on scaled features, reflecting the four unique cell types.
# - **Hierarchical Clustering**: Explores hierarchical relationships using the Ward linkage method, visualized via a dendrogram.
#
# These models are trained and evaluated to determine the best-performing approach for the given dataset.
#
# ## Evaluation Pipeline
# The evaluation pipeline ensures a comprehensive assessment of model performance:
# - **Data Preprocessing**: Missing values are dropped, `cellTypeName` is encoded using LabelEncoder, and features (`cellTypeName`, `cellType`) are scaled with StandardScaler. Images are resized to 64x64 pixels and normalized.
# - **Train-Test Split**: An 80/20 split is applied for both cancer detection and cell type classification tasks.
# - **Cross-Validation**: 5-fold cross-validation is performed for Logistic Regression and Random Forest to assess generalization.
# - **Metrics**: Models are evaluated using accuracy, precision, recall, F1-score (weighted averages), confusion matrices, and ROC curves with AUC scores.
# - **Visualizations**:
#   - Dataset distributions (bar plots for `cellTypeName` and `isCancerous`).
#   - Model performance (confusion matrices, ROC curves).
#   - Clustering results (K-Means scatter plot, Hierarchical Clustering dendrogram).
#   - Comparative analysis (bar plot of evaluation metrics).
# - **Model Selection**: The best-performing model (based on accuracy) is saved as `logistic_regression_model.pkl`, `random_forest_model.pkl`, or `cnn_model.h5`.
#
# ## Complete End-to-End Workflow
# The end-to-end pipeline integrates all stages from data loading to real-time testing:
# 1. **Data Loading**: The CSV file is read from `./dataset/data_labels_mainData.csv`, and images are loaded from `./dataset/images` using `ImageName` with `.png` extension.
# 2. **Preprocessing**: Data cleaning, encoding, scaling, and image preprocessing are performed.
# 3. **Model Training**: Logistic Regression, Random Forest, and CNN are trained on the preprocessed data.
# 4. **Clustering**: K-Means and Hierarchical Clustering are applied to identify patterns.
# 5. **Evaluation**: Models are evaluated with cross-validation and visualizations generated.
# 6. **Model Saving**: The best model is saved for future use.
# 7. **Real-Time Testing**: A sample image from the test set is selected, displayed, and predicted using the best model, with results (true vs. predicted cancer status and cell type) printed.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# Function to load and preprocess images from CSV
def load_and_preprocess_images(csv_path, img_folder='images', img_size=(64, 64), max_images=1000):
    try:
        # Load CSV
        df = pd.read_csv(csv_path)
        print("Dataset loaded successfully. Shape:", df.shape)
        
        # Select relevant columns and drop rows with missing values
        df = df[['ImageName', 'cellTypeName', 'isCancerous']].dropna()
        print("Dropped rows with missing values. Shape:", df.shape)
        
        # Encode cellTypeName
        le_cell = LabelEncoder()
        df['cellTypeName_encoded'] = le_cell.fit_transform(df['cellTypeName'])
        
        # Initialize lists for images and labels
        images, y_cancer, y_cell_type = [], [], []
        
        # Load images
        for idx, row in df.iterrows():
            if len(images) >= max_images:  # Limit to prevent memory issues
                break
            img_path = os.path.join(img_folder, row['ImageName'])
            if os.path.exists(img_path):
                try:
                    img = load_img(img_path, target_size=img_size)
                    img_array = img_to_array(img) / 255.0  # Normalize pixel values
                    images.append(img_array)
                    y_cancer.append(row['isCancerous'])
                    y_cell_type.append(row['cellTypeName_encoded'])
                except Exception as e:
                    print(f"Error loading image {img_path}: {e}")
            else:
                print(f"Image not found: {img_path}")
        
        # Convert to numpy arrays
        images = np.array(images)
        y_cancer = np.array(y_cancer)
        y_cell_type = np.array(y_cell_type)
        print(f"Loaded {len(images)} images successfully.")
        
        return images, y_cancer, y_cell_type, df, le_cell
    except Exception as e:
        print(f"Error loading/preprocessing data: {e}")
        return None, None, None, None, None

# Function to build and train multi-output CNN
def train_multi_output_cnn(X_train, y_train_cancer, y_train_cell_type, X_test, y_test_cancer, y_test_cell_type):
    # Define input layer
    input_layer = Input(shape=(64, 64, 3))
    
    # Convolutional base
    x = Conv2D(32, (3, 3), activation='relu')(input_layer)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    
    # Output layers
    cancer_output = Dense(1, activation='sigmoid', name='cancer_output')(x)  # Binary classification
    cell_type_output = Dense(len(np.unique(y_train_cell_type)), activation='softmax', name='cell_type_output')(x)  # Multi-class classification
    
    # Define model
    model = Model(inputs=input_layer, outputs=[cancer_output, cell_type_output])
    
    # Compile model
    model.compile(optimizer='adam',
                  loss={'cancer_output': 'binary_crossentropy', 'cell_type_output': 'sparse_categorical_crossentropy'},
                  metrics={'cancer_output': 'accuracy', 'cell_type_output': 'accuracy'})
    
    # Train model
    history = model.fit(X_train, {'cancer_output': y_train_cancer, 'cell_type_output': y_train_cell_type},
                        validation_data=(X_test, {'cancer_output': y_test_cancer, 'cell_type_output': y_test_cell_type}),
                        epochs=10, batch_size=32, verbose=1)
    
    # Evaluate model
    loss, cancer_loss, cell_type_loss, cancer_acc, cell_type_acc = model.evaluate(X_test, {'cancer_output': y_test_cancer, 'cell_type_output': y_test_cell_type}, verbose=0)
    print(f"Test Cancer Accuracy: {cancer_acc:.4f}")
    print(f"Test Cell Type Accuracy: {cell_type_acc:.4f}")
    
    # Predict on test set
    y_pred_cancer, y_pred_cell_type = model.predict(X_test)
    y_pred_cancer = (y_pred_cancer > 0.5).astype(int)
    y_pred_cell_type = np.argmax(y_pred_cell_type, axis=1)
    
    return model, cancer_acc, cell_type_acc, y_pred_cancer, y_pred_cell_type

# Function to visualize a sample prediction
def visualize_prediction(test_image, true_cancer, true_cell_type, pred_cancer, pred_cell_type, image_name, le_cell):
    plt.figure(figsize=(4, 4))
    plt.imshow(test_image)
    true_cancer_str = 'Cancerous' if true_cancer == 1 else 'Non-Cancerous'
    pred_cancer_str = 'Cancerous' if pred_cancer == 1 else 'Non-Cancerous'
    true_cell_type_str = le_cell.inverse_transform([true_cell_type])[0]
    pred_cell_type_str = le_cell.inverse_transform([pred_cell_type])[0]
    plt.title(f'Image: {image_name}\nTrue: {true_cell_type_str}, {true_cancer_str}\nPred: {pred_cell_type_str}, {pred_cancer_str}')
    plt.axis('off')
    plt.show()

# Function for real-time prediction
def predict_image(model, img_path, img_size=(64, 64), le_cell=None):
    try:
        img = load_img(img_path, target_size=img_size)
        img_array = img_to_array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)
        
        # Predict
        pred_cancer, pred_cell_type = model.predict(img_array)
        pred_cancer = (pred_cancer > 0.5).astype(int)[0][0]
        pred_cell_type = np.argmax(pred_cell_type, axis=1)[0]
        
        # Convert to human-readable format
        cancer_status = 'Cancerous' if pred_cancer == 1 else 'Non-Cancerous'
        cell_type = le_cell.inverse_transform([pred_cell_type])[0]
        
        return cell_type, cancer_status
    except Exception as e:
        print(f"Error predicting image: {e}")
        return None, None

# Main execution
if __name__ == "__main__":
    # Load and preprocess data
    X_images, y_cancer, y_cell_type, df, le_cell = load_and_preprocess_images('data_labels_mainData.csv')
    if X_images is None or len(X_images) == 0:
        print("No images loaded. Exiting.")
        exit()
    
    # Split data into train and test sets
    X_train_img, X_test_img, y_train_cancer, y_test_cancer, y_train_cell_type, y_test_cell_type = train_test_split(
        X_images, y_cancer, y_cell_type, test_size=0.2, random_state=42
    )
    
    # Train multi-output CNN
    model, cancer_acc, cell_type_acc, y_pred_cancer, y_pred_cell_type = train_multi_output_cnn(
        X_train_img, y_train_cancer, y_train_cell_type, X_test_img, y_test_cancer, y_test_cell_type
    )
    
    # Save the model
    model.save('multi_output_cnn_model.h5')
    print("Model saved as 'multi_output_cnn_model.h5'")
    
    # Visualize a sample prediction from test set
    test_idx = 0
    test_image = X_test_img[test_idx]
    true_cancer = y_test_cancer[test_idx]
    true_cell_type = y_test_cell_type[test_idx]
    pred_cancer = y_pred_cancer[test_idx][0]
    pred_cell_type = y_pred_cell_type[test_idx]
    image_name = df.iloc[df.index[df['ImageName'] == df['ImageName'].iloc[X_test_img.shape[0] + test_idx]]]['ImageName'].values[0]
    visualize_prediction(test_image, true_cancer, true_cell_type, pred_cancer, pred_cell_type, image_name, le_cell)
    
    # Real-time prediction example
    sample_image_path = os.path.join('images', '22405.png')  # Example image path
    if os.path.exists(sample_image_path):
        predicted_cell_type, predicted_cancer_status = predict_image(model, sample_image_path, le_cell=le_cell)
        if predicted_cell_type and predicted_cancer_status:
            print(f"\nReal-Time Prediction for {os.path.basename(sample_image_path)}:")
            print(f"Predicted Cell Type: {predicted_cell_type}")
            print(f"Predicted Cancer Status: {predicted_cancer_status}")
    else:
        print(f"Sample image {sample_image_path} not found.")
# Out:
# Dataset loaded successfully. Shape: (9896, 6)
# Dropped rows with missing values. Shape: (9896, 3)
# Image not found: images\22405.png
# Image not found: images\22406.png
# Image not found: images\22407.png
# Image not found: images\22408.png
# Image not found: images\22409.png
# Image not found: images\22410.png
# Image not found: images\22411.png
# Image not found: images\22412.png
# Image not found: images\22413.png
# Image not found: images\22414.png
# Image not found: images\22415.png
# Image not found: images\22417.png
# Image not found: images\22418.png
# Image not found: images\22419.png
# Image not found: images\22420.png
# Image not found: images\22421.png
# Image not found: images\22422.png
# Image not found: images\22423.png
# Image not found: images\22424.png
# Image not found: images\19035.png
# Image not found: images\19036.png
# Image not found: images\19037.png
# Image not found: images\19038.png
# Image not found: images\19039.png
# Image not found: images\19040.png
# Image not found: images\19041.png
# Image not found: images\19042.png
# Image not found: images\19043.png
# Image not found: images\19044.png
# Image not found: images\19045.png
# Image not found: images\19046.png
# Image not found: images\19047.png
# Image not found: images\19048.png
# Image not found: images\19049.png
# Image not found: images\19050.png
# Image not found: images\19051.png
# Image not found: images\19052.png
# Image not found: images\19053.png
# Image not found: images\19054.png
# Image not found: images\19055.png
# Image not found: images\19056.png
# Image not found: images\19057.png
# Image not found: images\19058.png
# Image not found: images\19059.png
# Image not found: images\19060.png
# Image not found: images\19061.png
# Image not found: images\19062.png
# Image not found: images\19063.png
# Image not found: images\19064.png
# Image not found: images\19066.png
# Image not found: images\19067.png
# Image not found: images\19068.png
# Image not found: images\18812.png
# Image not found: images\18813.png
# Image not found: images\18814.png
# Image not found: images\18815.png
# Image not found: images\18816.png
# Image not found: images\18817.png
# Image not found: images\18818.png
# Image not found: images\18819.png
# Image not found: images\18820.png
# Image not found: images\18821.png
# Image not found: images\18822.png
# Image not found: images\18823.png
# Image not found: images\18824.png
# Image not found: images\18825.png
# Image not found: images\18826.png
# Image not found: images\18827.png
# Image not found: images\18828.png
# Image not found: images\18830.png
# Image not found: images\18832.png
# Image not found: images\18833.png
# Image not found: images\18834.png
# Image not found: images\18835.png
# Image not found: images\18836.png
# Image not found: images\18837.png
# Image not found: images\18838.png
# Image not found: images\18839.png
# Image not found: images\18840.png
# Image not found: images\18841.png
# Image not found: images\18842.png
# Image not found: images\18843.png
# Image not found: images\18844.png
# Image not found: images\18845.png
# Image not found: images\18846.png
# Image not found: images\18847.png
# Image not found: images\18848.png
# Image not found: images\18849.png
# Image not found: images\18850.png
# Image not found: images\18851.png
# Image not found: images\18852.png
# Image not found: images\18853.png
# Image not found: images\18854.png
# Image not found: images\18855.png
# Image not found: images\18856.png
# Image not found: images\18857.png
# Image not found: images\18858.png
# Image not found: images\18859.png
# Image not found: images\18861.png
# Image not found: images\18862.png
# Image not found: images\18863.png
# Image not found: images\18865.png
# Image not found: images\18866.png
# Image not found: images\18867.png
# Image not found: images\18868.png
# Image not found: images\18869.png
# Image not found: images\18870.png
# Image not found: images\18871.png
# Image not found: images\18872.png
# Image not found: images\18873.png
# Image not found: images\18874.png
# Image not found: images\18875.png
# Image not found: images\18876.png
# Image not found: images\18877.png
# Image not found: images\18878.png
# Image not found: images\18879.png
# Image not found: images\18880.png
# Image not found: images\18881.png
# Image not found: images\18882.png
# Image not found: images\18885.png
# Image not found: images\18886.png
# Image not found: images\18887.png
# Image not found: images\18888.png
# Image not found: images\18889.png
# Image not found: images\18890.png
# Image not found: images\18891.png
# Image not found: images\18892.png
# Image not found: images\18893.png
# Image not found: images\18894.png
# Image not found: images\18895.png
# Image not found: images\18896.png
# Image not found: images\18897.png
# Image not found: images\18898.png
# Image not found: images\18899.png
# Image not found: images\18900.png
# Image not found: images\18901.png
# Image not found: images\18902.png
# Image not found: images\18903.png
# Image not found: images\18904.png
# Image not found: images\18905.png
# Image not found: images\18906.png
# Image not found: images\18907.png
# Image not found: images\18908.png
# Image not found: images\18909.png
# Image not found: images\18910.png
# Image not found: images\18911.png
# Image not found: images\18912.png
# Image not found: images\18913.png
# Image not found: images\18914.png
# Image not found: images\18915.png
# Image not found: images\18916.png
# Image not found: images\18917.png
# Image not found: images\18918.png
# Image not found: images\18919.png
# Image not found: images\18920.png
# Image not found: images\18921.png
# Image not found: images\18922.png
# Image not found: images\18923.png
# Image not found: images\18924.png
# Image not found: images\18925.png
# Image not found: images\18926.png
# Image not found: images\18927.png
# Image not found: images\18928.png
# Image not found: images\18929.png
# Image not found: images\18930.png
# Image not found: images\18931.png
# Image not found: images\18932.png
# Image not found: images\18933.png
# Image not found: images\18934.png
# Image not found: images\18935.png
# Image not found: images\18936.png
# Image not found: images\18937.png
# Image not found: images\18938.png
# Image not found: images\18939.png
# Image not found: images\18943.png
# Image not found: images\18944.png
# Image not found: images\18945.png
# Image not found: images\18946.png
# Image not found: images\18947.png
# Image not found: images\18948.png
# Image not found: images\18949.png
# Image not found: images\18950.png
# Image not found: images\18951.png
# Image not found: images\18952.png
# Image not found: images\18953.png
# Image not found: images\18954.png
# Image not found: images\18955.png
# Image not found: images\18956.png
# Image not found: images\18589.png
# Image not found: images\18590.png
# Image not found: images\18591.png
# Image not found: images\18592.png
# Image not found: images\18593.png
# Image not found: images\18594.png
# Image not found: images\18595.png
# Image not found: images\18596.png
# Image not found: images\18597.png
# Image not found: images\18598.png
# Image not found: images\18599.png
# Image not found: images\18600.png
# Image not found: images\18601.png
# Image not found: images\18602.png
# Image not found: images\18603.png
# Image not found: images\18604.png
# Image not found: images\18605.png
# Image not found: images\18606.png
# Image not found: images\18607.png
# Image not found: images\18608.png
# Image not found: images\18609.png
# Image not found: images\18610.png
# Image not found: images\18611.png
# Image not found: images\18612.png
# Image not found: images\18613.png
# Image not found: images\18614.png
# Image not found: images\18615.png
# Image not found: images\18616.png
# Image not found: images\18617.png
# Image not found: images\18618.png
# Image not found: images\18619.png
# Image not found: images\18620.png
# Image not found: images\18621.png
# Image not found: images\18622.png
# Image not found: images\18623.png
# Image not found: images\18624.png
# Image not found: images\18625.png
# Image not found: images\18626.png
# Image not found: images\18627.png
# Image not found: images\18631.png
# Image not found: images\18632.png
# Image not found: images\18633.png
# Image not found: images\18634.png
# Image not found: images\18635.png
# Image not found: images\18636.png
# Image not found: images\18637.png
# Image not found: images\18638.png
# Image not found: images\18639.png
# Image not found: images\18640.png
# Image not found: images\18641.png
# Image not found: images\18642.png
# Image not found: images\18643.png
# Image not found: images\18644.png
# Image not found: images\18645.png
# Image not found: images\18646.png
# Image not found: images\18647.png
# Image not found: images\18648.png
# Image not found: images\18649.png
# Image not found: images\18650.png
# Image not found: images\18651.png
# Image not found: images\18652.png
# Image not found: images\18653.png
# Image not found: images\18656.png
# Image not found: images\18657.png
# Image not found: images\18658.png
# Image not found: images\18659.png
# Image not found: images\18660.png
# Image not found: images\18661.png
# Image not found: images\18662.png
# Image not found: images\18663.png
# Image not found: images\18664.png
# Image not found: images\18665.png
# Image not found: images\18666.png
# Image not found: images\18667.png
# Image not found: images\18668.png
# Image not found: images\18669.png
# Image not found: images\18670.png
# Image not found: images\18671.png
# Image not found: images\18672.png
# Image not found: images\18673.png
# Image not found: images\18674.png
# Image not found: images\18675.png
# Image not found: images\18676.png
# Image not found: images\18677.png
# Image not found: images\18678.png
# Image not found: images\18679.png
# Image not found: images\18680.png
# Image not found: images\18681.png
# Image not found: images\18682.png
# Image not found: images\18683.png
# Image not found: images\18684.png
# Image not found: images\18685.png
# Image not found: images\18686.png
# Image not found: images\18687.png
# Image not found: images\18688.png
# Image not found: images\18689.png
# Image not found: images\18690.png
# Image not found: images\18691.png
# Image not found: images\18692.png
# Image not found: images\18693.png
# Image not found: images\18694.png
# Image not found: images\18695.png
# Image not found: images\18696.png
# Image not found: images\18697.png
# Image not found: images\18698.png
# Image not found: images\18699.png
# Image not found: images\18700.png
# Image not found: images\18701.png
# Image not found: images\18702.png
# Image not found: images\18703.png
# Image not found: images\18704.png
# Image not found: images\18706.png
# Image not found: images\18707.png
# Image not found: images\18708.png
# Image not found: images\18709.png
# Image not found: images\18710.png
# Image not found: images\18711.png
# Image not found: images\18712.png
# Image not found: images\18713.png
# Image not found: images\18714.png
# Image not found: images\18715.png
# Image not found: images\18716.png
# Image not found: images\18717.png
# Image not found: images\18718.png
# Image not found: images\18719.png
# Image not found: images\18720.png
# Image not found: images\18721.png
# Image not found: images\132.png
# Image not found: images\133.png
# Image not found: images\134.png
# Image not found: images\135.png
# Image not found: images\136.png
# Image not found: images\137.png
# Image not found: images\138.png
# Image not found: images\140.png
# Image not found: images\141.png
# Image not found: images\142.png
# Image not found: images\143.png
# Image not found: images\144.png
# Image not found: images\145.png
# Image not found: images\146.png
# Image not found: images\147.png
# Image not found: images\148.png
# Image not found: images\149.png
# Image not found: images\150.png
# Image not found: images\152.png
# Image not found: images\153.png
# Image not found: images\154.png
# Image not found: images\155.png
# Image not found: images\156.png
# Image not found: images\157.png
# Image not found: images\158.png
# Image not found: images\161.png
# Image not found: images\162.png
# Image not found: images\163.png
# Image not found: images\164.png
# Image not found: images\165.png
# Image not found: images\166.png
# Image not found: images\167.png
# Image not found: images\168.png
# Image not found: images\169.png
# Image not found: images\171.png
# Image not found: images\172.png
# Image not found: images\173.png
# Image not found: images\174.png
# Image not found: images\175.png
# Image not found: images\176.png
# Image not found: images\177.png
# Image not found: images\178.png
# Image not found: images\179.png
# Image not found: images\180.png
# Image not found: images\181.png
# Image not found: images\182.png
# Image not found: images\183.png
# Image not found: images\184.png
# Image not found: images\185.png
# Image not found: images\186.png
# Image not found: images\187.png
# Image not found: images\188.png
# Image not found: images\189.png
# Image not found: images\190.png
# Image not found: images\191.png
# Image not found: images\192.png
# Image not found: images\193.png
# Image not found: images\194.png
# Image not found: images\195.png
# Image not found: images\196.png
# Image not found: images\197.png
# Image not found: images\198.png
# Image not found: images\199.png
# Image not found: images\200.png
# Image not found: images\201.png
# Image not found: images\202.png
# Image not found: images\203.png
# Image not found: images\204.png
# Image not found: images\205.png
# Image not found: images\206.png
# Image not found: images\207.png
# Image not found: images\208.png
# Image not found: images\209.png
# Image not found: images\210.png
# Image not found: images\211.png
# Image not found: images\212.png
# Image not found: images\213.png
# Image not found: images\214.png
# Image not found: images\215.png
# Image not found: images\216.png
# Image not found: images\217.png
# Image not found: images\218.png
# Image not found: images\220.png
# Image not found: images\221.png
# Image not found: images\222.png
# Image not found: images\223.png
# Image not found: images\224.png
# Image not found: images\225.png
# Image not found: images\226.png
# Image not found: images\227.png
# Image not found: images\228.png
# Image not found: images\229.png
# Image not found: images\230.png
# Image not found: images\231.png
# Image not found: images\232.png
# Image not found: images\233.png
# Image not found: images\234.png
# Image not found: images\235.png
# Image not found: images\236.png
# Image not found: images\237.png
# Image not found: images\238.png
# Image not found: images\239.png
# Image not found: images\240.png
# Image not found: images\241.png
# Image not found: images\242.png
# Image not found: images\243.png
# Image not found: images\244.png
# Image not found: images\245.png
# Image not found: images\246.png
# Image not found: images\247.png
# Image not found: images\248.png
# Image not found: images\249.png
# Image not found: images\250.png
# Image not found: images\251.png
# Image not found: images\252.png
# Image not found: images\253.png
# Image not found: images\254.png
# Image not found: images\255.png
# Image not found: images\256.png
# Image not found: images\257.png
# Image not found: images\258.png
# Image not found: images\259.png
# Image not found: images\260.png
# Image not found: images\261.png
# Image not found: images\262.png
# Image not found: images\263.png
# Image not found: images\264.png
# Image not found: images\265.png
# Image not found: images\269.png
# Image not found: images\270.png
# Image not found: images\271.png
# Image not found: images\273.png
# Image not found: images\274.png
# Image not found: images\275.png
# Image not found: images\276.png
# Image not found: images\277.png
# Image not found: images\278.png
# Image not found: images\279.png
# Image not found: images\280.png
# Image not found: images\281.png
# Image not found: images\282.png
# Image not found: images\283.png
# Image not found: images\284.png
# Image not found: images\285.png
# Image not found: images\286.png
# Image not found: images\287.png
# Image not found: images\288.png
# Image not found: images\289.png
# Image not found: images\290.png
# Image not found: images\291.png
# Image not found: images\292.png
# Image not found: images\293.png
# Image not found: images\294.png
# Image not found: images\295.png
# Image not found: images\296.png
# Image not found: images\297.png
# Image not found: images\298.png
# Image not found: images\299.png
# Image not found: images\300.png
# Image not found: images\301.png
# Image not found: images\302.png
# Image not found: images\303.png
# Image not found: images\304.png
# Image not found: images\305.png
# Image not found: images\306.png
# Image not found: images\307.png
# Image not found: images\308.png
# Image not found: images\309.png
# Image not found: images\310.png
# Image not found: images\4083.png
# Image not found: images\4084.png
# Image not found: images\4085.png
# Image not found: images\4086.png
# Image not found: images\4087.png
# Image not found: images\4088.png
# Image not found: images\4089.png
# Image not found: images\4090.png
# Image not found: images\4092.png
# Image not found: images\4095.png
# Image not found: images\4096.png
# Image not found: images\4097.png
# Image not found: images\4098.png
# Image not found: images\4099.png
# Image not found: images\4100.png
# Image not found: images\4101.png
# Image not found: images\4102.png
# Image not found: images\4103.png
# Image not found: images\4104.png
# Image not found: images\4105.png
# Image not found: images\4106.png
# Image not found: images\4107.png
# Image not found: images\4108.png
# Image not found: images\4109.png
# Image not found: images\4110.png
# Image not found: images\4111.png
# Image not found: images\4112.png
# Image not found: images\4113.png
# Image not found: images\4114.png
# Image not found: images\4115.png
# Image not found: images\4116.png
# Image not found: images\4117.png
# Image not found: images\4119.png
# Image not found: images\4121.png
# Image not found: images\4122.png
# Image not found: images\4123.png
# Image not found: images\4124.png
# Image not found: images\4125.png
# Image not found: images\4126.png
# Image not found: images\4127.png
# Image not found: images\4128.png
# Image not found: images\4129.png
# Image not found: images\4130.png
# Image not found: images\4131.png
# Image not found: images\4132.png
# Image not found: images\4133.png
# Image not found: images\4134.png
# Image not found: images\4135.png
# Image not found: images\4136.png
# Image not found: images\4137.png
# Image not found: images\4138.png
# Image not found: images\4139.png
# Image not found: images\4140.png
# Image not found: images\4141.png
# Image not found: images\4142.png
# Image not found: images\4143.png
# Image not found: images\4144.png
# Image not found: images\4145.png
# Image not found: images\4147.png
# Image not found: images\4148.png
# Image not found: images\4149.png
# Image not found: images\4150.png
# Image not found: images\4151.png
# Image not found: images\4152.png
# Image not found: images\4153.png
# Image not found: images\4154.png
# Image not found: images\4155.png
# Image not found: images\4156.png
# Image not found: images\4157.png
# Image not found: images\4158.png
# Image not found: images\4159.png
# Image not found: images\4160.png
# Image not found: images\4161.png
# Image not found: images\4162.png
# Image not found: images\4164.png
# Image not found: images\4165.png
# Image not found: images\4166.png
# Image not found: images\4167.png
# Image not found: images\4168.png
# Image not found: images\4169.png
# Image not found: images\4170.png
# Image not found: images\4171.png
# Image not found: images\4172.png
# Image not found: images\4173.png
# Image not found: images\4174.png
# Image not found: images\4175.png
# Image not found: images\4176.png
# Image not found: images\4177.png
# Image not found: images\4178.png
# Image not found: images\4179.png
# Image not found: images\4180.png
# Image not found: images\4181.png
# Image not found: images\4182.png
# Image not found: images\4183.png
# Image not found: images\4184.png
# Image not found: images\4185.png
# Image not found: images\4186.png
# Image not found: images\4187.png
# Image not found: images\4188.png
# Image not found: images\4189.png
# Image not found: images\4190.png
# Image not found: images\4191.png
# Image not found: images\4192.png
# Image not found: images\4193.png
# Image not found: images\4194.png
# Image not found: images\4195.png
# Image not found: images\4196.png
# Image not found: images\4197.png
# Image not found: images\4198.png
# Image not found: images\4199.png
# Image not found: images\4200.png
# Image not found: images\4201.png
# Image not found: images\4202.png
# Image not found: images\4203.png
# Image not found: images\4204.png
# Image not found: images\4205.png
# Image not found: images\4206.png
# Image not found: images\4207.png
# Image not found: images\4208.png
# Image not found: images\4209.png
# Image not found: images\4210.png
# Image not found: images\4211.png
# Image not found: images\4212.png
# Image not found: images\4213.png
# Image not found: images\4214.png
# Image not found: images\4215.png
# Image not found: images\4216.png
# Image not found: images\4217.png
# Image not found: images\4218.png
# Image not found: images\4219.png
# Image not found: images\4220.png
# Image not found: images\4221.png
# Image not found: images\4222.png
# Image not found: images\4223.png
# Image not found: images\4224.png
# Image not found: images\4225.png
# Image not found: images\4226.png
# Image not found: images\4227.png
# Image not found: images\4228.png
# Image not found: images\4229.png
# Image not found: images\4230.png
# Image not found: images\4231.png
# Image not found: images\4232.png
# Image not found: images\4233.png
# Image not found: images\4234.png
# Image not found: images\4237.png
# Image not found: images\4239.png
# Image not found: images\4240.png
# Image not found: images\4241.png
# Image not found: images\4242.png
# Image not found: images\4243.png
# Image not found: images\4244.png
# Image not found: images\4246.png
# Image not found: images\4247.png
# Image not found: images\4248.png
# Image not found: images\4249.png
# Image not found: images\4250.png
# Image not found: images\4251.png
# Image not found: images\4252.png
# Image not found: images\4253.png
# Image not found: images\4254.png
# Image not found: images\4256.png
# Image not found: images\4257.png
# Image not found: images\4258.png
# Image not found: images\4259.png
# Image not found: images\4260.png
# Image not found: images\4261.png
# Image not found: images\4263.png
# Image not found: images\4264.png
# Image not found: images\4265.png
# Image not found: images\4268.png
# Image not found: images\4269.png
# Image not found: images\4270.png
# Image not found: images\4271.png
# Image not found: images\4272.png
# Image not found: images\4273.png
# Image not found: images\4274.png
# Image not found: images\4275.png
# Image not found: images\4276.png
# Image not found: images\4277.png
# Image not found: images\4279.png
# Image not found: images\4280.png
# Image not found: images\4281.png
# Image not found: images\4282.png
# Image not found: images\4283.png
# Image not found: images\4284.png
# Image not found: images\4285.png
# Image not found: images\4286.png
# Image not found: images\4287.png
# Image not found: images\4288.png
# Image not found: images\4289.png
# Image not found: images\4290.png
# Image not found: images\4291.png
# Image not found: images\4292.png
# Image not found: images\4293.png
# Image not found: images\4294.png
# Image not found: images\4295.png
# Image not found: images\4297.png
# Image not found: images\8981.png
# Image not found: images\8982.png
# Image not found: images\8983.png
# Image not found: images\8984.png
# Image not found: images\8985.png
# Image not found: images\8986.png
# Image not found: images\8987.png
# Image not found: images\8988.png
# Image not found: images\8989.png
# Image not found: images\8990.png
# Image not found: images\8991.png
# Image not found: images\8992.png
# Image not found: images\8993.png
# Image not found: images\8994.png
# Image not found: images\8995.png
# Image not found: images\8996.png
# Image not found: images\8997.png
# Image not found: images\8998.png
# Image not found: images\9000.png
# Image not found: images\9001.png
# Image not found: images\9002.png
# Image not found: images\9003.png
# Image not found: images\9004.png
# Image not found: images\9005.png
# Image not found: images\9006.png
# Image not found: images\9007.png
# Image not found: images\9008.png
# Image not found: images\9009.png
# Image not found: images\9010.png
# Image not found: images\9011.png
# Image not found: images\9013.png
# Image not found: images\9014.png
# Image not found: images\9015.png
# Image not found: images\9016.png
# Image not found: images\9017.png
# Image not found: images\9018.png
# Image not found: images\9019.png
# Image not found: images\9020.png
# Image not found: images\9021.png
# Image not found: images\9022.png
# Image not found: images\9023.png
# Image not found: images\9024.png
# Image not found: images\9025.png
# Image not found: images\9026.png
# Image not found: images\9027.png
# Image not found: images\9028.png
# Image not found: images\9029.png
# Image not found: images\9030.png
# Image not found: images\9031.png
# Image not found: images\9032.png
# Image not found: images\9033.png
# Image not found: images\9034.png
# Image not found: images\9035.png
# Image not found: images\9036.png
# Image not found: images\9037.png
# Image not found: images\9038.png
# Image not found: images\9039.png
# Image not found: images\9040.png
# Image not found: images\9041.png
# Image not found: images\9042.png
# Image not found: images\9043.png
# Image not found: images\9044.png
# Image not found: images\9045.png
# Image not found: images\9046.png
# Image not found: images\9047.png
# Image not found: images\9048.png
# Image not found: images\9049.png
# Image not found: images\9050.png
# Image not found: images\9051.png
# Image not found: images\9052.png
# Image not found: images\9053.png
# Image not found: images\9054.png
# Image not found: images\9055.png
# Image not found: images\9056.png
# Image not found: images\9057.png
# Image not found: images\9058.png
# Image not found: images\9059.png
# Image not found: images\9060.png
# Image not found: images\9061.png
# Image not found: images\9062.png
# Image not found: images\9063.png
# Image not found: images\9064.png
# Image not found: images\9065.png
# Image not found: images\9066.png
# Image not found: images\9067.png
# Image not found: images\9068.png
# Image not found: images\9069.png
# Image not found: images\9070.png
# Image not found: images\9071.png
# Image not found: images\9072.png
# Image not found: images\9073.png
# Image not found: images\9074.png
# Image not found: images\9075.png
# Image not found: images\9076.png
# Image not found: images\9077.png
# Image not found: images\9078.png
# Image not found: images\9079.png
# Image not found: images\9080.png
# Image not found: images\9081.png
# Image not found: images\9082.png
# Image not found: images\9083.png
# Image not found: images\9084.png
# Image not found: images\9085.png
# Image not found: images\9086.png
# Image not found: images\9087.png
# Image not found: images\9088.png
# Image not found: images\9089.png
# Image not found: images\9090.png
# Image not found: images\9091.png
# Image not found: images\9092.png
# Image not found: images\9093.png
# Image not found: images\9094.png
# Image not found: images\9095.png
# Image not found: images\9096.png
# Image not found: images\9097.png
# Image not found: images\9098.png
# Image not found: images\9099.png
# Image not found: images\9100.png
# Image not found: images\9101.png
# Image not found: images\9102.png
# Image not found: images\9103.png
# Image not found: images\9104.png
# Image not found: images\9105.png
# Image not found: images\9106.png
# Image not found: images\9107.png
# Image not found: images\9108.png
# Image not found: images\9109.png
# Image not found: images\9110.png
# Image not found: images\9111.png
# Image not found: images\9112.png
# Image not found: images\9113.png
# Image not found: images\9114.png
# Image not found: images\9115.png
# Image not found: images\9116.png
# Image not found: images\9117.png
# Image not found: images\9118.png
# Image not found: images\9119.png
# Image not found: images\9120.png
# Image not found: images\9121.png
# Image not found: images\9122.png
# Image not found: images\9123.png
# Image not found: images\9124.png
# Image not found: images\9125.png
# Image not found: images\9126.png
# Image not found: images\9127.png
# Image not found: images\9128.png
# Image not found: images\9129.png
# Image not found: images\9130.png
# Image not found: images\9131.png
# Image not found: images\9132.png
# Image not found: images\9133.png
# Image not found: images\9134.png
# Image not found: images\9135.png
# Image not found: images\9136.png
# Image not found: images\9137.png
# Image not found: images\9138.png
# Image not found: images\9139.png
# Image not found: images\9140.png
# Image not found: images\9141.png
# Image not found: images\9142.png
# Image not found: images\9143.png
# Image not found: images\9144.png
# Image not found: images\9145.png
# Image not found: images\9146.png
# Image not found: images\9147.png
# Image not found: images\9148.png
# Image not found: images\9149.png
# Image not found: images\9150.png
# Image not found: images\9151.png
# Image not found: images\9152.png
# Image not found: images\9154.png
# Image not found: images\9157.png
# Image not found: images\9158.png
# Image not found: images\9159.png
# Image not found: images\9162.png
# Image not found: images\9163.png
# Image not found: images\9164.png
# Image not found: images\9165.png
# Image not found: images\9166.png
# Image not found: images\9167.png
# Image not found: images\9168.png
# Image not found: images\9169.png
# Image not found: images\9170.png
# Image not found: images\9171.png
# Image not found: images\9172.png
# Image not found: images\9173.png
# Image not found: images\9174.png
# Image not found: images\9175.png
# Image not found: images\9176.png
# Image not found: images\9177.png
# Image not found: images\9178.png
# Image not found: images\9179.png
# Image not found: images\9180.png
# Image not found: images\9181.png
# Image not found: images\9182.png
# Image not found: images\9183.png
# Image not found: images\9184.png
# Image not found: images\9185.png
# Image not found: images\9186.png
# Image not found: images\9187.png
# Image not found: images\9188.png
# Image not found: images\9189.png
# Image not found: images\9190.png
# Image not found: images\9191.png
# Image not found: images\9192.png
# Image not found: images\9193.png
# Image not found: images\9194.png
# Image not found: images\9195.png
# Image not found: images\9196.png
# Image not found: images\9197.png
# Image not found: images\9198.png
# Image not found: images\9199.png
# Image not found: images\9200.png
# Image not found: images\9201.png
# Image not found: images\9202.png
# Image not found: images\9203.png
# Image not found: images\9204.png
# Image not found: images\9205.png
# Image not found: images\9206.png
# Image not found: images\9207.png
# Image not found: images\9209.png
# Image not found: images\9211.png
# Image not found: images\9212.png
# Image not found: images\9213.png
# Image not found: images\9214.png
# Image not found: images\9215.png
# Image not found: images\9216.png
# Image not found: images\9217.png
# Image not found: images\9218.png
# Image not found: images\9219.png
# Image not found: images\9220.png
# Image not found: images\9221.png
# Image not found: images\9222.png
# Image not found: images\9223.png
# Image not found: images\9224.png
# Image not found: images\9225.png
# Image not found: images\9226.png
# Image not found: images\9227.png
# Image not found: images\9228.png
# Image not found: images\9229.png
# Image not found: images\9230.png
# Image not found: images\9231.png
# Image not found: images\9232.png
# Image not found: images\9236.png
# Image not found: images\9237.png
# Image not found: images\9238.png
# Image not found: images\9240.png
# Image not found: images\9241.png
# Image not found: images\9244.png
# Image not found: images\9246.png
# Image not found: images\9247.png
# Image not found: images\9248.png
# Image not found: images\9249.png
# Image not found: images\4664.png
# Image not found: images\4665.png
# Image not found: images\4666.png
# Image not found: images\4667.png
# Image not found: images\4668.png
# Image not found: images\4669.png
# Image not found: images\4670.png
# Image not found: images\4672.png
# Image not found: images\4673.png
# Image not found: images\4674.png
# Image not found: images\4677.png
# Image not found: images\4678.png
# Image not found: images\4681.png
# Image not found: images\4682.png
# Image not found: images\4684.png
# Image not found: images\4685.png
# Image not found: images\4686.png
# Image not found: images\4687.png
# Image not found: images\4688.png
# Image not found: images\4689.png
# Image not found: images\4690.png
# Image not found: images\4691.png
# Image not found: images\4692.png
# Image not found: images\4693.png
# Image not found: images\4694.png
# Image not found: images\4696.png
# Image not found: images\4697.png
# Image not found: images\4698.png
# Image not found: images\4699.png
# Image not found: images\4700.png
# Image not found: images\4701.png
# Image not found: images\4702.png
# Image not found: images\4703.png
# Image not found: images\4704.png
# Image not found: images\4705.png
# Image not found: images\4706.png
# Image not found: images\4707.png
# Image not found: images\4708.png
# Image not found: images\4709.png
# Image not found: images\4710.png
# Image not found: images\4711.png
# Image not found: images\4712.png
# Image not found: images\4713.png
# Image not found: images\4714.png
# Image not found: images\4715.png
# Image not found: images\4717.png
# Image not found: images\4718.png
# Image not found: images\4719.png
# Image not found: images\4720.png
# Image not found: images\4721.png
# Image not found: images\4722.png
# Image not found: images\4723.png
# Image not found: images\4724.png
# Image not found: images\4725.png
# Image not found: images\4726.png
# Image not found: images\4727.png
# Image not found: images\4728.png
# Image not found: images\4729.png
# Image not found: images\4730.png
# Image not found: images\4731.png
# Image not found: images\4732.png
# Image not found: images\4733.png
# Image not found: images\4734.png
# Image not found: images\4735.png
# Image not found: images\4736.png
# Image not found: images\4737.png
# Image not found: images\4738.png
# Image not found: images\4739.png
# Image not found: images\4740.png
# Image not found: images\4741.png
# Image not found: images\4742.png
# Image not found: images\4744.png
# Image not found: images\4745.png
# Image not found: images\4746.png
# Image not found: images\4747.png
# Image not found: images\4748.png
# Image not found: images\4749.png
# Image not found: images\4750.png
# Image not found: images\4751.png
# Image not found: images\4752.png
# Image not found: images\4753.png
# Image not found: images\4754.png
# Image not found: images\4755.png
# Image not found: images\4756.png
# Image not found: images\4757.png
# Image not found: images\4758.png
# Image not found: images\4759.png
# Image not found: images\4760.png
# Image not found: images\4761.png
# Image not found: images\4762.png
# Image not found: images\4763.png
# Image not found: images\4764.png
# Image not found: images\4765.png
# Image not found: images\4766.png
# Image not found: images\4767.png
# Image not found: images\4768.png
# Image not found: images\4769.png
# Image not found: images\4770.png
# Image not found: images\4771.png
# Image not found: images\4772.png
# Image not found: images\4773.png
# Image not found: images\4774.png
# Image not found: images\4775.png
# Image not found: images\4776.png
# Image not found: images\4777.png
# Image not found: images\4778.png
# Image not found: images\4779.png
# Image not found: images\4780.png
# Image not found: images\4781.png
# Image not found: images\4782.png
# Image not found: images\4783.png
# Image not found: images\4784.png
# Image not found: images\4785.png
# Image not found: images\4786.png
# Image not found: images\4787.png
# Image not found: images\4788.png
# Image not found: images\4789.png
# Image not found: images\4790.png
# Image not found: images\4791.png
# Image not found: images\4792.png
# Image not found: images\4793.png
# Image not found: images\4794.png
# Image not found: images\4795.png
# Image not found: images\4797.png
# Image not found: images\4798.png
# Image not found: images\4799.png
# Image not found: images\4800.png
# Image not found: images\4801.png
# Image not found: images\4802.png
# Image not found: images\4803.png
# Image not found: images\4804.png
# Image not found: images\4805.png
# Image not found: images\4806.png
# Image not found: images\4807.png
# Image not found: images\4808.png
# Image not found: images\4809.png
# Image not found: images\4810.png
# Image not found: images\4811.png
# Image not found: images\4812.png
# Image not found: images\4813.png
# Image not found: images\4814.png
# Image not found: images\4815.png
# Image not found: images\4816.png
# Image not found: images\4817.png
# Image not found: images\4820.png
# Image not found: images\4821.png
# Image not found: images\4822.png
# Image not found: images\4823.png
# Image not found: images\4824.png
# Image not found: images\4825.png
# Image not found: images\4826.png
# Image not found: images\4827.png
# Image not found: images\4828.png
# Image not found: images\4829.png
# Image not found: images\4830.png
# Image not found: images\4831.png
# Image not found: images\4832.png
# Image not found: images\4833.png
# Image not found: images\4834.png
# Image not found: images\4835.png
# Image not found: images\4836.png
# Image not found: images\4837.png
# Image not found: images\4838.png
# Image not found: images\4839.png
# Image not found: images\4840.png
# Image not found: images\4841.png
# Image not found: images\4842.png
# Image not found: images\4843.png
# Image not found: images\4844.png
# Image not found: images\4845.png
# Image not found: images\4846.png
# Image not found: images\4847.png
# Image not found: images\4848.png
# Image not found: images\4849.png
# Image not found: images\4850.png
# Image not found: images\4851.png
# Image not found: images\4852.png
# Image not found: images\4853.png
# Image not found: images\4854.png
# Image not found: images\4855.png
# Image not found: images\4856.png
# Image not found: images\4857.png
# Image not found: images\4858.png
# Image not found: images\4859.png
# Image not found: images\4860.png
# Image not found: images\4861.png
# Image not found: images\4862.png
# Image not found: images\4863.png
# Image not found: images\4864.png
# Image not found: images\4865.png
# Image not found: images\4866.png
# Image not found: images\4867.png
# Image not found: images\4868.png
# Image not found: images\4869.png
# Image not found: images\4870.png
# Image not found: images\4871.png
# Image not found: images\4872.png
# Image not found: images\4873.png
# Image not found: images\4874.png
# Image not found: images\4875.png
# Image not found: images\4876.png
# Image not found: images\4877.png
# Image not found: images\4878.png
# Image not found: images\4879.png
# Image not found: images\4880.png
# Image not found: images\4881.png
# Image not found: images\4882.png
# Image not found: images\4883.png
# Image not found: images\4884.png
# Image not found: images\4885.png
# Image not found: images\4886.png
# Image not found: images\4887.png
# Image not found: images\4888.png
# Image not found: images\4889.png
# Image not found: images\4890.png
# Image not found: images\4891.png
# Image not found: images\4892.png
# Image not found: images\4893.png
# Image not found: images\4894.png
# Image not found: images\4895.png
# Image not found: images\4896.png
# Image not found: images\4897.png
# Image not found: images\4898.png
# Image not found: images\4899.png
# Image not found: images\4900.png
# Image not found: images\4901.png
# Image not found: images\4902.png
# Image not found: images\4903.png
# Image not found: images\4904.png
# Image not found: images\4905.png
# Image not found: images\4906.png
# Image not found: images\4907.png
# Image not found: images\4908.png
# Image not found: images\4909.png
# Image not found: images\4910.png
# Image not found: images\4911.png
# Image not found: images\4912.png
# Image not found: images\4913.png
# Image not found: images\4914.png
# Image not found: images\4915.png
# Image not found: images\4916.png
# Image not found: images\4917.png
# Image not found: images\4918.png
# Image not found: images\4919.png
# Image not found: images\4920.png
# Image not found: images\4921.png
# Image not found: images\4922.png
# Image not found: images\4923.png
# Image not found: images\4924.png
# Image not found: images\4925.png
# Image not found: images\4926.png
# Image not found: images\4927.png
# Image not found: images\4928.png
# Image not found: images\4929.png
# Image not found: images\4930.png
# Image not found: images\4931.png
# Image not found: images\4932.png
# Image not found: images\4933.png
# Image not found: images\4934.png
# Image not found: images\4935.png
# Image not found: images\4936.png
# Image not found: images\4937.png
# Image not found: images\4938.png
# Image not found: images\4939.png
# Image not found: images\4940.png
# Image not found: images\4941.png
# Image not found: images\4942.png
# Image not found: images\4943.png
# Image not found: images\4944.png
# Image not found: images\4945.png
# Image not found: images\4946.png
# Image not found: images\4947.png
# Image not found: images\4948.png
# Image not found: images\4949.png
# Image not found: images\4950.png
# Image not found: images\4951.png
# Image not found: images\4952.png
# Image not found: images\4953.png
# Image not found: images\4954.png
# Image not found: images\4955.png
# Image not found: images\4956.png
# Image not found: images\4957.png
# Image not found: images\4958.png
# Image not found: images\4959.png
# Image not found: images\4960.png
# Image not found: images\4961.png
# Image not found: images\4962.png
# Image not found: images\4963.png
# Image not found: images\4967.png
# Image not found: images\4968.png
# Image not found: images\4970.png
# Image not found: images\4971.png
# Image not found: images\4972.png
# Image not found: images\4974.png
# Image not found: images\4975.png
# Image not found: images\4976.png
# Image not found: images\4977.png
# Image not found: images\4978.png
# Image not found: images\4979.png
# Image not found: images\4980.png
# Image not found: images\4981.png
# Image not found: images\4982.png
# Image not found: images\4983.png
# Image not found: images\4984.png
# Image not found: images\4985.png
# Image not found: images\4986.png
# Image not found: images\4987.png
# Image not found: images\4988.png
# Image not found: images\4989.png
# Image not found: images\4990.png
# Image not found: images\4991.png
# Image not found: images\4992.png
# Image not found: images\4993.png
# Image not found: images\4994.png
# Image not found: images\4995.png
# Image not found: images\4996.png
# Image not found: images\4997.png
# Image not found: images\4998.png
# Image not found: images\4999.png
# Image not found: images\5000.png
# Image not found: images\5001.png
# Image not found: images\5002.png
# Image not found: images\5003.png
# Image not found: images\5004.png
# Image not found: images\5005.png
# Image not found: images\5006.png
# Image not found: images\5007.png
# Image not found: images\5008.png
# Image not found: images\5009.png
# Image not found: images\5010.png
# Image not found: images\5011.png
# Image not found: images\5012.png
# Image not found: images\7677.png
# Image not found: images\7680.png
# Image not found: images\7681.png
# Image not found: images\7682.png
# Image not found: images\7683.png
# Image not found: images\7684.png
# Image not found: images\7685.png
# Image not found: images\7686.png
# Image not found: images\7687.png
# Image not found: images\7688.png
# Image not found: images\7689.png
# Image not found: images\7690.png
# Image not found: images\7691.png
# Image not found: images\7692.png
# Image not found: images\7693.png
# Image not found: images\7694.png
# Image not found: images\7695.png
# Image not found: images\7696.png
# Image not found: images\7697.png
# Image not found: images\7698.png
# Image not found: images\7699.png
# Image not found: images\7700.png
# Image not found: images\7701.png
# Image not found: images\7702.png
# Image not found: images\7703.png
# Image not found: images\7704.png
# Image not found: images\7705.png
# Image not found: images\7706.png
# Image not found: images\7707.png
# Image not found: images\7708.png
# Image not found: images\7709.png
# Image not found: images\7710.png
# Image not found: images\7712.png
# Image not found: images\7713.png
# Image not found: images\7715.png
# Image not found: images\7716.png
# Image not found: images\7717.png
# Image not found: images\7718.png
# Image not found: images\7719.png
# Image not found: images\7721.png
# Image not found: images\7722.png
# Image not found: images\7723.png
# Image not found: images\7725.png
# Image not found: images\7726.png
# Image not found: images\7727.png
# Image not found: images\7728.png
# Image not found: images\7729.png
# Image not found: images\7730.png
# Image not found: images\7731.png
# Image not found: images\7735.png
# Image not found: images\7736.png
# Image not found: images\7737.png
# Image not found: images\7738.png
# Image not found: images\7739.png
# Image not found: images\7740.png
# Image not found: images\7741.png
# Image not found: images\7742.png
# Image not found: images\7743.png
# Image not found: images\7744.png
# Image not found: images\7745.png
# Image not found: images\7746.png
# Image not found: images\7747.png
# Image not found: images\7748.png
# Image not found: images\7749.png
# Image not found: images\7750.png
# Image not found: images\7751.png
# Image not found: images\7752.png
# Image not found: images\7753.png
# Image not found: images\7754.png
# Image not found: images\7755.png
# Image not found: images\7756.png
# Image not found: images\7757.png
# Image not found: images\7758.png
# Image not found: images\7759.png
# Image not found: images\7760.png
# Image not found: images\7761.png
# Image not found: images\7762.png
# Image not found: images\7763.png
# Image not found: images\7764.png
# Image not found: images\7765.png
# Image not found: images\7766.png
# Image not found: images\7767.png
# Image not found: images\7768.png
# Image not found: images\7769.png
# Image not found: images\7770.png
# Image not found: images\7771.png
# Image not found: images\7772.png
# Image not found: images\7773.png
# Image not found: images\7774.png
# Image not found: images\7778.png
# Image not found: images\7779.png
# Image not found: images\7780.png
# Image not found: images\7781.png
# Image not found: images\7782.png
# Image not found: images\7783.png
# Image not found: images\7784.png
# Image not found: images\7785.png
# Image not found: images\7786.png
# Image not found: images\7787.png
# Image not found: images\7788.png
# Image not found: images\7789.png
# Image not found: images\7790.png
# Image not found: images\7792.png
# Image not found: images\7793.png
# Image not found: images\7794.png
# Image not found: images\7795.png
# Image not found: images\7796.png
# Image not found: images\7797.png
# Image not found: images\7798.png
# Image not found: images\7799.png
# Image not found: images\7800.png
# Image not found: images\7801.png
# Image not found: images\7802.png
# Image not found: images\7803.png
# Image not found: images\7804.png
# Image not found: images\7805.png
# Image not found: images\7807.png
# Image not found: images\7808.png
# Image not found: images\7809.png
# Image not found: images\7810.png
# Image not found: images\7811.png
# Image not found: images\7812.png
# Image not found: images\7813.png
# Image not found: images\7814.png
# Image not found: images\7815.png
# Image not found: images\7816.png
# Image not found: images\7817.png
# Image not found: images\7818.png
# Image not found: images\7819.png
# Image not found: images\7820.png
# Image not found: images\7821.png
# Image not found: images\7823.png
# Image not found: images\7825.png
# Image not found: images\7826.png
# Image not found: images\7827.png
# Image not found: images\7828.png
# Image not found: images\7829.png
# Image not found: images\7830.png
# Image not found: images\7831.png
# Image not found: images\7832.png
# Image not found: images\7833.png
# Image not found: images\7834.png
# Image not found: images\7835.png
# Image not found: images\7836.png
# Image not found: images\7837.png
# Image not found: images\7838.png
# Image not found: images\7839.png
# Image not found: images\7840.png
# Image not found: images\7841.png
# Image not found: images\7842.png
# Image not found: images\7843.png
# Image not found: images\7844.png
# Image not found: images\7845.png
# Image not found: images\7846.png
# Image not found: images\7847.png
# Image not found: images\7848.png
# Image not found: images\7849.png
# Image not found: images\7850.png
# Image not found: images\7851.png
# Image not found: images\7852.png
# Image not found: images\7853.png
# Image not found: images\7854.png
# Image not found: images\7855.png
# Image not found: images\7856.png
# Image not found: images\7857.png
# Image not found: images\7858.png
# Image not found: images\7859.png
# Image not found: images\7860.png
# Image not found: images\7861.png
# Image not found: images\7862.png
# Image not found: images\7863.png
# Image not found: images\7864.png
# Image not found: images\7865.png
# Image not found: images\7866.png
# Image not found: images\7867.png
# Image not found: images\7868.png
# Image not found: images\7869.png
# Image not found: images\7870.png
# Image not found: images\7871.png
# Image not found: images\7872.png
# ...
# Image not found: images\22252.png
# Image not found: images\22253.png
# Image not found: images\22254.png
# Image not found: images\22255.png
# Image not found: images\22256.png
# Image not found: images\22257.png
# Image not found: images\22258.png
# Image not found: images\22259.png
# Image not found: images\22260.png
# Image not found: images\22261.png
# Image not found: images\22262.png
# Image not found: images\22263.png
# Image not found: images\22264.png
# Image not found: images\22265.png
# Image not found: images\22266.png
# Image not found: images\22268.png
# Image not found: images\22269.png
# Image not found: images\22270.png
# Image not found: images\22271.png
# Image not found: images\22272.png
# Image not found: images\22273.png
# Image not found: images\22274.png
# Image not found: images\22275.png
# Image not found: images\22276.png
# Image not found: images\22277.png
# Image not found: images\22278.png
# Image not found: images\22280.png
# Image not found: images\22281.png
# Image not found: images\22282.png
# Image not found: images\22283.png
# Image not found: images\22284.png
# Image not found: images\22285.png
# Image not found: images\22286.png
# Image not found: images\22287.png
# Image not found: images\22288.png
# Image not found: images\22289.png
# Image not found: images\22290.png
# Image not found: images\22291.png
# Image not found: images\22292.png
# Image not found: images\22293.png
# Image not found: images\22294.png
# Image not found: images\22295.png
# Image not found: images\22296.png
# Image not found: images\22297.png
# Image not found: images\22298.png
# Image not found: images\22299.png
# Image not found: images\22300.png
# Image not found: images\22301.png
# Image not found: images\22302.png
# Image not found: images\22303.png
# Image not found: images\22304.png
# Image not found: images\22305.png
# Image not found: images\22306.png
# Image not found: images\22307.png
# Image not found: images\22308.png
# Image not found: images\22309.png
# Image not found: images\22310.png
# Image not found: images\22311.png
# Image not found: images\22312.png
# Image not found: images\22313.png
# Image not found: images\22314.png
# Image not found: images\22315.png
# Image not found: images\22316.png
# Image not found: images\22317.png
# Image not found: images\22318.png
# Image not found: images\22319.png
# Image not found: images\22320.png
# Image not found: images\22321.png
# Image not found: images\22322.png
# Image not found: images\22323.png
# Image not found: images\22324.png
# Image not found: images\22325.png
# Image not found: images\22326.png
# Image not found: images\22327.png
# Image not found: images\22328.png
# Image not found: images\22329.png
# Image not found: images\22330.png
# Image not found: images\22331.png
# Image not found: images\22332.png
# Image not found: images\22333.png
# Image not found: images\22334.png
# Image not found: images\22337.png
# Image not found: images\22338.png
# Image not found: images\22339.png
# Image not found: images\22340.png
# Image not found: images\22341.png
# Image not found: images\22342.png
# Image not found: images\22343.png
# Image not found: images\22344.png
# Image not found: images\22345.png
# Image not found: images\22346.png
# Image not found: images\22347.png
# Image not found: images\22348.png
# Image not found: images\22349.png
# Image not found: images\22350.png
# Image not found: images\22351.png
# Image not found: images\22352.png
# Image not found: images\22353.png
# Image not found: images\22354.png
# Image not found: images\22355.png
# Image not found: images\22356.png
# Image not found: images\22357.png
# Image not found: images\22358.png
# Image not found: images\22359.png
# Image not found: images\22360.png
# Image not found: images\22361.png
# Image not found: images\22362.png
# Image not found: images\22363.png
# Image not found: images\22364.png
# Image not found: images\22365.png
# Image not found: images\22366.png
# Image not found: images\22367.png
# Image not found: images\22368.png
# Image not found: images\22369.png
# Image not found: images\22370.png
# Image not found: images\22371.png
# Image not found: images\22372.png
# Image not found: images\22373.png
# Image not found: images\22374.png
# Image not found: images\22376.png
# Image not found: images\22377.png
# Image not found: images\22379.png
# Image not found: images\22380.png
# Image not found: images\22381.png
# Image not found: images\22382.png
# Image not found: images\22383.png
# Image not found: images\22384.png
# Image not found: images\22385.png
# Image not found: images\22386.png
# Image not found: images\22387.png
# Image not found: images\22388.png
# Image not found: images\22389.png
# Image not found: images\22390.png
# Image not found: images\22391.png
# Image not found: images\22392.png
# Image not found: images\22393.png
# Image not found: images\22394.png
# Image not found: images\22395.png
# Image not found: images\22396.png
# Image not found: images\22397.png
# Image not found: images\22398.png
# Image not found: images\22399.png
# Image not found: images\22400.png
# Image not found: images\22401.png
# Image not found: images\22402.png
# Image not found: images\22403.png
# Image not found: images\22404.png
# Image not found: images\17697.png
# Image not found: images\17698.png
# Image not found: images\17699.png
# Image not found: images\17700.png
# Image not found: images\17701.png
# Image not found: images\17702.png
# Image not found: images\17703.png
# Image not found: images\17704.png
# Image not found: images\17708.png
# Image not found: images\17709.png
# Image not found: images\17710.png
# Image not found: images\17711.png
# Image not found: images\17712.png
# Image not found: images\17713.png
# Image not found: images\17714.png
# Image not found: images\17716.png
# Image not found: images\17717.png
# Image not found: images\17718.png
# Image not found: images\17719.png
# Image not found: images\17720.png
# Image not found: images\17721.png
# Image not found: images\17722.png
# Image not found: images\17723.png
# Image not found: images\17724.png
# Image not found: images\17725.png
# Image not found: images\17726.png
# Image not found: images\17728.png
# Image not found: images\17729.png
# Image not found: images\17731.png
# Image not found: images\17732.png
# Image not found: images\17733.png
# Image not found: images\17734.png
# Image not found: images\17735.png
# Image not found: images\17738.png
# Image not found: images\17739.png
# Image not found: images\17741.png
# Image not found: images\17742.png
# Image not found: images\17743.png
# Image not found: images\17744.png
# Image not found: images\17745.png
# Image not found: images\17746.png
# Image not found: images\17747.png
# Image not found: images\17748.png
# Image not found: images\17749.png
# Image not found: images\17750.png
# Image not found: images\17751.png
# Image not found: images\17752.png
# Image not found: images\17753.png
# Image not found: images\17754.png
# Image not found: images\17755.png
# Image not found: images\17756.png
# Image not found: images\17757.png
# Image not found: images\17758.png
# Image not found: images\17759.png
# Image not found: images\17760.png
# Image not found: images\17761.png
# Image not found: images\17762.png
# Image not found: images\17763.png
# Image not found: images\17764.png
# Image not found: images\17766.png
# Image not found: images\17767.png
# Image not found: images\17768.png
# Image not found: images\17769.png
# Image not found: images\17770.png
# Image not found: images\17771.png
# Image not found: images\17772.png
# Image not found: images\17773.png
# Image not found: images\17774.png
# Image not found: images\17775.png
# Image not found: images\17776.png
# Image not found: images\17777.png
# Image not found: images\17778.png
# Image not found: images\17779.png
# Image not found: images\17780.png
# Image not found: images\17781.png
# Image not found: images\17782.png
# Image not found: images\17783.png
# Image not found: images\17784.png
# Image not found: images\17785.png
# Image not found: images\17786.png
# Image not found: images\17787.png
# Image not found: images\17788.png
# Image not found: images\17789.png
# Image not found: images\17790.png
# Image not found: images\17791.png
# Image not found: images\17792.png
# Image not found: images\17793.png
# Image not found: images\17794.png
# Image not found: images\17795.png
# Image not found: images\17796.png
# Image not found: images\17797.png
# Image not found: images\17798.png
# Image not found: images\17799.png
# Image not found: images\17800.png
# Image not found: images\17801.png
# Image not found: images\17802.png
# Image not found: images\17804.png
# Image not found: images\17805.png
# Image not found: images\17806.png
# Image not found: images\17807.png
# Image not found: images\17808.png
# Image not found: images\17809.png
# Image not found: images\17810.png
# Image not found: images\17811.png
# Image not found: images\17812.png
# Image not found: images\17813.png
# Image not found: images\17814.png
# Image not found: images\17815.png
# Image not found: images\17816.png
# Image not found: images\17818.png
# Image not found: images\17819.png
# Image not found: images\17820.png
# Image not found: images\17821.png
# Image not found: images\17822.png
# Image not found: images\17823.png
# Image not found: images\1503.png
# Image not found: images\1504.png
# Image not found: images\1505.png
# Image not found: images\1506.png
# Image not found: images\1507.png
# Image not found: images\1508.png
# Image not found: images\1509.png
# Image not found: images\1510.png
# Image not found: images\1512.png
# Image not found: images\1514.png
# Image not found: images\1515.png
# Image not found: images\1516.png
# Image not found: images\1517.png
# Image not found: images\1518.png
# Image not found: images\1519.png
# Image not found: images\1520.png
# Image not found: images\1521.png
# Image not found: images\1522.png
# Image not found: images\1523.png
# Image not found: images\1524.png
# Image not found: images\1526.png
# Image not found: images\1527.png
# Image not found: images\1528.png
# Image not found: images\1529.png
# Image not found: images\1530.png
# Image not found: images\1531.png
# Image not found: images\1532.png
# Image not found: images\1533.png
# Image not found: images\1534.png
# Image not found: images\1535.png
# Image not found: images\1536.png
# Image not found: images\1537.png
# Image not found: images\1538.png
# Image not found: images\1539.png
# Image not found: images\1540.png
# Image not found: images\1541.png
# Image not found: images\1542.png
# Image not found: images\1544.png
# Image not found: images\1545.png
# Image not found: images\1546.png
# Image not found: images\1547.png
# Image not found: images\1548.png
# Image not found: images\1549.png
# Image not found: images\1552.png
# Image not found: images\1553.png
# Image not found: images\1554.png
# Image not found: images\1555.png
# Image not found: images\1556.png
# Image not found: images\1557.png
# Image not found: images\1558.png
# Image not found: images\1559.png
# Image not found: images\1560.png
# Image not found: images\1561.png
# Image not found: images\1562.png
# Image not found: images\1563.png
# Image not found: images\1564.png
# Image not found: images\1565.png
# Image not found: images\1566.png
# Image not found: images\1568.png
# Image not found: images\1569.png
# Image not found: images\1570.png
# Image not found: images\1571.png
# Image not found: images\1573.png
# Image not found: images\1574.png
# Image not found: images\1575.png
# Image not found: images\1576.png
# Image not found: images\1577.png
# Image not found: images\1578.png
# Image not found: images\1579.png
# Image not found: images\1580.png
# Image not found: images\1581.png
# Image not found: images\1582.png
# Image not found: images\1583.png
# Image not found: images\1584.png
# Image not found: images\1585.png
# Image not found: images\1586.png
# Image not found: images\1587.png
# Image not found: images\1588.png
# Image not found: images\1589.png
# Image not found: images\1590.png
# Image not found: images\1591.png
# Image not found: images\1592.png
# Image not found: images\1593.png
# Image not found: images\1594.png
# Image not found: images\1595.png
# Image not found: images\1596.png
# Image not found: images\1597.png
# Image not found: images\1598.png
# Image not found: images\1599.png
# Image not found: images\1600.png
# Image not found: images\1601.png
# Image not found: images\1602.png
# Image not found: images\1603.png
# Image not found: images\1604.png
# Image not found: images\1605.png
# Image not found: images\1606.png
# Image not found: images\1607.png
# Image not found: images\1608.png
# Image not found: images\1609.png
# Image not found: images\1610.png
# Image not found: images\1611.png
# Image not found: images\1612.png
# Image not found: images\1613.png
# Image not found: images\1614.png
# Image not found: images\1615.png
# Image not found: images\1616.png
# Image not found: images\1617.png
# Image not found: images\1618.png
# Image not found: images\1619.png
# Image not found: images\1624.png
# Image not found: images\1625.png
# Image not found: images\1626.png
# Image not found: images\1627.png
# Image not found: images\1628.png
# Image not found: images\1629.png
# Loaded 0 images successfully.
# No images loaded. Exiting.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 148
#     145     exit()
#     147 # Split data into train and test sets
# --> 148 X_train_img, X_test_img, y_train_cancer, y_test_cancer, y_train_cell_type, y_test_cell_type = train_test_split(
#     149     X_images, y_cancer, y_cell_type, test_size=0.2, random_state=42
#     150 )
#     152 # Train multi-output CNN
#     153 model, cancer_acc, cell_type_acc, y_pred_cancer, y_pred_cell_type = train_multi_output_cnn(
#     154     X_train_img, y_train_cancer, y_train_cell_type, X_test_img, y_test_cancer, y_test_cell_type
#     155 )
#
# File d:\Abdul Rehman\Iqra khan ML project Help\cancer-cell-type-classification\venv\lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File d:\Abdul Rehman\Iqra khan ML project Help\cancer-cell-type-classification\venv\lib\site-packages\sklearn\model_selection\_split.py:2919, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2916 arrays = indexable(*arrays)
#    2918 n_samples = _num_samples(arrays[0])
# -> 2919 n_train, n_test = _validate_shuffle_split(
#    2920     n_samples, test_size, train_size, default_test_size=0.25
#    2921 )
#    2923 if shuffle is False:
#    2924     if stratify is not None:
#
# File d:\Abdul Rehman\Iqra khan ML project Help\cancer-cell-type-classification\venv\lib\site-packages\sklearn\model_selection\_split.py:2499, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2496 n_train, n_test = int(n_train), int(n_test)
#    2498 if n_train == 0:
# -> 2499     raise ValueError(
#    2500         "With n_samples={}, test_size={} and train_size={}, the "
#    2501         "resulting train set will be empty. Adjust any of the "
#    2502         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2503     )
#    2505 return n_train, n_test
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
